# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model2.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 1.81292, saving model to model2.weights.best.hdf5
# 28s - loss: 1.6050 - acc: 0.4206 - val_loss: 1.8129 - val_acc: 0.4030
# Epoch 2/100
# Epoch 00001: val_loss improved from 1.81292 to 1.21601, saving model to model2.weights.best.hdf5
# 27s - loss: 1.2799 - acc: 0.5400 - val_loss: 1.2160 - val_acc: 0.5796
# Epoch 3/100
# Epoch 00002: val_loss improved from 1.21601 to 1.14350, saving model to model2.weights.best.hdf5
# 28s - loss: 1.1636 - acc: 0.5890 - val_loss: 1.1435 - val_acc: 0.6140
# Epoch 4/100
# Epoch 00003: val_loss improved from 1.14350 to 1.02606, saving model to model2.weights.best.hdf5
# 29s - loss: 1.0999 - acc: 0.6132 - val_loss: 1.0261 - val_acc: 0.6402
# Epoch 5/100
# Epoch 00004: val_loss did not improve
# 27s - loss: 1.0641 - acc: 0.6283 - val_loss: 1.1150 - val_acc: 0.6234
# Epoch 6/100
# Epoch 00005: val_loss improved from 1.02606 to 0.93469, saving model to model2.weights.best.hdf5
# 36s - loss: 1.0464 - acc: 0.6399 - val_loss: 0.9347 - val_acc: 0.6796
# Epoch 7/100
# Epoch 00006: val_loss did not improve
# 39s - loss: 1.0382 - acc: 0.6434 - val_loss: 1.0524 - val_acc: 0.6358
# Epoch 8/100
# Epoch 00007: val_loss did not improve
# 38s - loss: 1.0348 - acc: 0.6496 - val_loss: 0.9881 - val_acc: 0.6618
# Epoch 9/100
# Epoch 00008: val_loss did not improve
# 38s - loss: 1.0423 - acc: 0.6493 - val_loss: 1.0796 - val_acc: 0.6400
# Epoch 10/100
# Epoch 00009: val_loss did not improve
# 37s - loss: 1.0405 - acc: 0.6461 - val_loss: 1.0088 - val_acc: 0.6536
# Epoch 11/100
# Epoch 00010: val_loss did not improve
# 30s - loss: 1.0459 - acc: 0.6475 - val_loss: 1.0497 - val_acc: 0.6272
# Epoch 12/100
# Epoch 00011: val_loss did not improve
# 27s - loss: 1.0629 - acc: 0.6426 - val_loss: 1.0012 - val_acc: 0.6534
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 27s - loss: 1.0803 - acc: 0.6372 - val_loss: 1.0951 - val_acc: 0.6408
# Epoch 14/100
# Epoch 00013: val_loss did not improve
# 28s - loss: 1.0947 - acc: 0.6330 - val_loss: 1.0840 - val_acc: 0.6242
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 27s - loss: 1.1068 - acc: 0.6306 - val_loss: 1.1401 - val_acc: 0.6114
# Epoch 16/100
# Epoch 00015: val_loss did not improve
# 27s - loss: 1.1175 - acc: 0.6278 - val_loss: 1.0117 - val_acc: 0.6492
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 27s - loss: 1.1408 - acc: 0.6186 - val_loss: 1.2861 - val_acc: 0.6022
# Epoch 18/100
# Epoch 00017: val_loss did not improve
# 27s - loss: 1.1535 - acc: 0.6162 - val_loss: 1.1619 - val_acc: 0.6042
# Epoch 19/100
# Epoch 00018: val_loss did not improve
# 27s - loss: 1.1617 - acc: 0.6117 - val_loss: 1.7894 - val_acc: 0.5560
# Epoch 20/100
# Epoch 00019: val_loss did not improve
# 27s - loss: 1.1922 - acc: 0.6072 - val_loss: 1.1043 - val_acc: 0.6330
# Epoch 21/100
# Epoch 00020: val_loss did not improve
# 28s - loss: 1.1896 - acc: 0.6050 - val_loss: 1.3598 - val_acc: 0.5474
# Epoch 22/100
# Epoch 00021: val_loss did not improve
# 33s - loss: 1.2062 - acc: 0.6034 - val_loss: 1.1859 - val_acc: 0.5972
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 28s - loss: 1.2180 - acc: 0.5975 - val_loss: 1.3283 - val_acc: 0.5340
# Epoch 24/100
# Epoch 00023: val_loss did not improve
# 29s - loss: 1.2490 - acc: 0.5868 - val_loss: 1.3093 - val_acc: 0.6354
# Epoch 25/100
# Epoch 00024: val_loss did not improve
# 30s - loss: 1.2542 - acc: 0.5890 - val_loss: 1.4522 - val_acc: 0.5986
# Epoch 26/100
# Epoch 00025: val_loss did not improve
# 29s - loss: 1.2628 - acc: 0.5812 - val_loss: 1.1347 - val_acc: 0.6162
# Epoch 27/100
# Epoch 00026: val_loss did not improve
# 29s - loss: 1.2777 - acc: 0.5763 - val_loss: 1.4108 - val_acc: 0.5436
# Epoch 28/100
# Epoch 00027: val_loss did not improve
# 27s - loss: 1.2882 - acc: 0.5735 - val_loss: 1.6485 - val_acc: 0.4960
# Epoch 29/100
# Epoch 00028: val_loss did not improve
# 30s - loss: 1.3231 - acc: 0.5655 - val_loss: 1.3950 - val_acc: 0.5416
# Epoch 30/100
# Epoch 00029: val_loss did not improve
# 38s - loss: 1.3292 - acc: 0.5598 - val_loss: 1.4876 - val_acc: 0.5048
# Epoch 31/100
# Epoch 00030: val_loss did not improve
# 39s - loss: 1.3418 - acc: 0.5527 - val_loss: 2.0383 - val_acc: 0.5694
# Epoch 32/100
# Epoch 00031: val_loss did not improve
# 38s - loss: 1.3655 - acc: 0.5488 - val_loss: 1.2642 - val_acc: 0.5838
# Epoch 33/100
# Epoch 00032: val_loss did not improve
# 39s - loss: 1.3953 - acc: 0.5408 - val_loss: 1.2775 - val_acc: 0.5498
# Epoch 34/100
# Epoch 00033: val_loss did not improve
# 38s - loss: 1.4116 - acc: 0.5335 - val_loss: 1.4192 - val_acc: 0.5584
# Epoch 35/100
# Epoch 00034: val_loss did not improve
# 38s - loss: 1.4136 - acc: 0.5323 - val_loss: 1.3878 - val_acc: 0.5688
# Epoch 36/100
# Epoch 00035: val_loss did not improve
# 38s - loss: 1.4335 - acc: 0.5263 - val_loss: 2.0803 - val_acc: 0.5232
# Epoch 37/100
# Epoch 00036: val_loss did not improve
# 34s - loss: 1.4407 - acc: 0.5153 - val_loss: 1.3101 - val_acc: 0.5474
# Epoch 38/100
# Epoch 00037: val_loss did not improve
# 26s - loss: 1.4501 - acc: 0.5164 - val_loss: 1.3514 - val_acc: 0.5524
# Epoch 39/100
# Epoch 00038: val_loss did not improve
# 26s - loss: 1.4803 - acc: 0.5073 - val_loss: 1.6367 - val_acc: 0.4822
# Epoch 40/100
# Epoch 00039: val_loss did not improve
# 27s - loss: 1.4840 - acc: 0.5058 - val_loss: 1.2853 - val_acc: 0.5490
# Epoch 41/100
# Epoch 00040: val_loss did not improve
# 27s - loss: 1.4983 - acc: 0.5008 - val_loss: 1.2454 - val_acc: 0.5610
# Epoch 42/100
# Epoch 00041: val_loss did not improve
# 27s - loss: 1.5192 - acc: 0.4918 - val_loss: 1.3563 - val_acc: 0.5342
# Epoch 43/100
# Epoch 00042: val_loss did not improve
# 26s - loss: 1.5388 - acc: 0.4828 - val_loss: 1.3310 - val_acc: 0.5380
# Epoch 44/100
# Epoch 00043: val_loss did not improve
# 27s - loss: 1.5479 - acc: 0.4797 - val_loss: 1.3377 - val_acc: 0.5050
# Epoch 45/100
# Epoch 00044: val_loss did not improve
# 27s - loss: 1.5670 - acc: 0.4759 - val_loss: 1.7912 - val_acc: 0.4790
# Epoch 46/100
# Epoch 00045: val_loss did not improve
# 27s - loss: 1.5654 - acc: 0.4723 - val_loss: 2.3365 - val_acc: 0.4242
# Epoch 47/100
# Epoch 00046: val_loss did not improve
# 27s - loss: 1.5735 - acc: 0.4704 - val_loss: 1.3992 - val_acc: 0.5208
# Epoch 48/100
# Epoch 00047: val_loss did not improve
# 27s - loss: 1.5919 - acc: 0.4605 - val_loss: 1.4611 - val_acc: 0.5114
# Epoch 49/100
# Epoch 00048: val_loss did not improve
# 27s - loss: 1.6072 - acc: 0.4548 - val_loss: 1.7162 - val_acc: 0.3642
# Epoch 50/100
# Epoch 00049: val_loss did not improve
# 27s - loss: 1.6115 - acc: 0.4507 - val_loss: 1.4929 - val_acc: 0.4908
# Epoch 51/100
# Epoch 00050: val_loss did not improve
# 27s - loss: 1.6436 - acc: 0.4482 - val_loss: 1.6210 - val_acc: 0.4140
# Epoch 52/100
# Epoch 00051: val_loss did not improve
# 26s - loss: 1.6466 - acc: 0.4401 - val_loss: 1.3901 - val_acc: 0.5128
# Epoch 53/100
# Epoch 00052: val_loss did not improve
# 26s - loss: 1.6620 - acc: 0.4330 - val_loss: 1.5892 - val_acc: 0.4468
# Epoch 54/100
# Epoch 00053: val_loss did not improve
# 29s - loss: 1.6800 - acc: 0.4222 - val_loss: 1.5717 - val_acc: 0.4358
# Epoch 55/100
# Epoch 00054: val_loss did not improve
# 37s - loss: 1.6837 - acc: 0.4240 - val_loss: 1.3121 - val_acc: 0.5314
# Epoch 56/100
# Epoch 00055: val_loss did not improve
# 37s - loss: 1.6953 - acc: 0.4206 - val_loss: 1.4829 - val_acc: 0.4788
# Epoch 57/100
# Epoch 00056: val_loss did not improve
# 36s - loss: 1.7036 - acc: 0.4177 - val_loss: 1.9721 - val_acc: 0.4228
# Epoch 58/100
# Epoch 00057: val_loss did not improve
# 30s - loss: 1.7117 - acc: 0.4119 - val_loss: 1.5009 - val_acc: 0.5308
# Epoch 59/100
# Epoch 00058: val_loss did not improve
# 27s - loss: 1.7077 - acc: 0.4150 - val_loss: 1.4688 - val_acc: 0.5018
# Epoch 60/100
# Epoch 00059: val_loss did not improve
# 28s - loss: 1.7138 - acc: 0.4118 - val_loss: 1.3711 - val_acc: 0.5208
# Epoch 61/100
# Epoch 00060: val_loss did not improve
# 34s - loss: 1.7157 - acc: 0.4127 - val_loss: 2.2058 - val_acc: 0.3050
# Epoch 62/100
# Epoch 00061: val_loss did not improve
# 41s - loss: 1.7178 - acc: 0.4088 - val_loss: 1.7191 - val_acc: 0.4032
# Epoch 63/100
# Epoch 00062: val_loss did not improve
# 39s - loss: 1.7188 - acc: 0.4071 - val_loss: 2.8354 - val_acc: 0.4298
# Epoch 64/100
# Epoch 00063: val_loss did not improve
# 34s - loss: 1.7233 - acc: 0.4057 - val_loss: 1.6090 - val_acc: 0.4618
# Epoch 65/100
# Epoch 00064: val_loss did not improve
# 31s - loss: 1.7326 - acc: 0.4033 - val_loss: 7.5930 - val_acc: 0.2160
# Epoch 66/100
# Epoch 00065: val_loss did not improve
# 32s - loss: 1.7216 - acc: 0.4026 - val_loss: 1.5592 - val_acc: 0.4572
# Epoch 67/100
# Epoch 00066: val_loss did not improve
# 30s - loss: 1.7338 - acc: 0.3984 - val_loss: 1.5657 - val_acc: 0.4108
# Epoch 68/100
# Epoch 00067: val_loss did not improve
# 30s - loss: 1.7251 - acc: 0.3998 - val_loss: 1.6360 - val_acc: 0.4274
# Epoch 69/100
# Epoch 00068: val_loss did not improve
# 29s - loss: 1.7358 - acc: 0.3970 - val_loss: 1.4559 - val_acc: 0.4800
# Epoch 70/100
# Epoch 00069: val_loss did not improve
# 30s - loss: 1.7466 - acc: 0.3927 - val_loss: 1.5146 - val_acc: 0.4824
# Epoch 71/100
# Epoch 00070: val_loss did not improve
# 28s - loss: 1.7406 - acc: 0.3949 - val_loss: 1.5061 - val_acc: 0.4594
# Epoch 72/100
# Epoch 00071: val_loss did not improve
# 33s - loss: 1.7468 - acc: 0.3924 - val_loss: 1.7581 - val_acc: 0.4022
# Epoch 73/100
# Epoch 00072: val_loss did not improve
# 32s - loss: 1.7549 - acc: 0.3873 - val_loss: 1.4961 - val_acc: 0.4584
# Epoch 74/100
# Epoch 00073: val_loss did not improve
# 32s - loss: 1.7630 - acc: 0.3835 - val_loss: 1.6509 - val_acc: 0.4104
# Epoch 75/100
# Epoch 00074: val_loss did not improve
# 32s - loss: 1.7697 - acc: 0.3838 - val_loss: 1.4994 - val_acc: 0.4828
# Epoch 76/100
# Epoch 00075: val_loss did not improve
# 33s - loss: 1.7804 - acc: 0.3844 - val_loss: 1.6941 - val_acc: 0.3606
# Epoch 77/100
# Epoch 00076: val_loss did not improve
# 30s - loss: 1.7630 - acc: 0.3862 - val_loss: 1.4176 - val_acc: 0.5182
# Epoch 78/100
# Epoch 00077: val_loss did not improve
# 30s - loss: 1.7711 - acc: 0.3816 - val_loss: 1.4346 - val_acc: 0.4852
# Epoch 79/100
# Epoch 00078: val_loss did not improve
# 30s - loss: 1.7734 - acc: 0.3817 - val_loss: 1.7461 - val_acc: 0.3856
# Epoch 80/100
# Epoch 00079: val_loss did not improve
# 27s - loss: 1.7800 - acc: 0.3788 - val_loss: 1.4545 - val_acc: 0.4660
# Epoch 81/100
# Epoch 00080: val_loss did not improve
# 27s - loss: 1.7967 - acc: 0.3717 - val_loss: 1.4780 - val_acc: 0.4480
# Epoch 82/100
# Epoch 00081: val_loss did not improve
# 27s - loss: 1.8031 - acc: 0.3715 - val_loss: 1.5389 - val_acc: 0.4608
# Epoch 83/100
# Epoch 00082: val_loss did not improve
# 27s - loss: 1.8171 - acc: 0.3632 - val_loss: 1.7015 - val_acc: 0.3516
# Epoch 84/100
# Epoch 00083: val_loss did not improve
# 28s - loss: 1.8135 - acc: 0.3685 - val_loss: 1.7035 - val_acc: 0.3824
# Epoch 85/100
# Epoch 00084: val_loss did not improve
# 29s - loss: 1.8100 - acc: 0.3648 - val_loss: 1.6409 - val_acc: 0.4308
# Epoch 86/100
# Epoch 00085: val_loss did not improve
# 31s - loss: 1.8137 - acc: 0.3688 - val_loss: 1.4700 - val_acc: 0.4554
# Epoch 87/100
# Epoch 00086: val_loss did not improve
# 34s - loss: 1.8311 - acc: 0.3615 - val_loss: 1.6224 - val_acc: 0.4256
# Epoch 88/100
# Epoch 00087: val_loss did not improve
# 34s - loss: 1.8181 - acc: 0.3681 - val_loss: 1.6324 - val_acc: 0.3818
# Epoch 89/100
# Epoch 00088: val_loss did not improve
# 33s - loss: 1.8226 - acc: 0.3603 - val_loss: 1.5534 - val_acc: 0.4096
# Epoch 90/100
# Epoch 00089: val_loss did not improve
# 33s - loss: 1.8209 - acc: 0.3641 - val_loss: 1.4581 - val_acc: 0.4584
# Epoch 91/100
# Epoch 00090: val_loss did not improve
# 33s - loss: 1.8225 - acc: 0.3607 - val_loss: 1.5415 - val_acc: 0.4354
# Epoch 92/100
# Epoch 00091: val_loss did not improve
# 27s - loss: 1.8545 - acc: 0.3524 - val_loss: 1.7107 - val_acc: 0.3644
# Epoch 93/100
# Epoch 00092: val_loss did not improve
# 27s - loss: 1.8514 - acc: 0.3502 - val_loss: 1.8012 - val_acc: 0.4094
# Epoch 94/100
# Epoch 00093: val_loss did not improve
# 27s - loss: 1.8690 - acc: 0.3470 - val_loss: 1.6770 - val_acc: 0.4644
# Epoch 95/100
# Epoch 00094: val_loss did not improve
# 28s - loss: 1.8502 - acc: 0.3492 - val_loss: 3.9348 - val_acc: 0.2580
# Epoch 96/100
# Epoch 00095: val_loss did not improve
# 29s - loss: 1.8648 - acc: 0.3459 - val_loss: 1.6873 - val_acc: 0.3946
# Epoch 97/100
# Epoch 00096: val_loss did not improve
# 27s - loss: 1.8769 - acc: 0.3485 - val_loss: 1.6673 - val_acc: 0.3780
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 27s - loss: 1.8704 - acc: 0.3409 - val_loss: 1.7446 - val_acc: 0.3376
# Epoch 99/100
# Epoch 00098: val_loss did not improve
# 27s - loss: 1.8817 - acc: 0.3430 - val_loss: 1.6367 - val_acc: 0.4270
# Epoch 100/100
# Epoch 00099: val_loss did not improve
# 27s - loss: 1.8889 - acc: 0.3375 - val_loss: 2.0401 - val_acc: 0.4202

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6598

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
